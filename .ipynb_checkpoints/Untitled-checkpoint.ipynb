# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([3.2, 3.21, 3.22, 3.24, 3.25, 3.26, 3.27, 3.28])
y = np.array([6.038, 6.004, 5.966, 5.935, 5.903, 5.860, 5.817, 5.796])
y2 = -2.9773 * x + 15.565

# %%
plt.figure(figsize=(10, 7))
plt.plot(x, y2, label='y = -2.9773x + 15.565')

plt.xticks(np.arange(3.2, 3.31, 0.01))
plt.yticks(np.arange(5.75, ))
# Out:
# ([<matplotlib.axis.XTick at 0x24a456e6d20>,
# ...
#  [Text(3.2, 0, '3.20'),
#   Text(3.21, 0, '3.21'),
#   Text(3.2199999999999998, 0, '3.22'),
#   Text(3.2299999999999995, 0, '3.23'),
#   Text(3.2399999999999993, 0, '3.24'),
#   Text(3.249999999999999, 0, '3.25'),
#   Text(3.259999999999999, 0, '3.26'),
#   Text(3.2699999999999987, 0, '3.27'),
#   Text(3.2799999999999985, 0, '3.28'),
#   Text(3.2899999999999983, 0, '3.29'),
#   Text(3.299999999999998, 0, '3.30')])

# %%
đ
